# %%
# Assignment 6: Process some clusters of your choice and then visualize them to see the distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# Load the dataset
df = pd.read_csv('customer_data_records.csv')  
print(df)
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)
# 0             1                 117                      20
# 1             2                 107                      59
# 2             3                  29                      36
# 3             4                 121                      19
# 4             5                  86                      90
# ..          ...                 ...                     ...
# 169         170                 111                      76
# 170         171                 138                      87
# 171         172                  84                      15
# 172         173                 107                      92
# 173         174                  17                      98
#
# [174 rows x 3 columns]

# %%
# Select features for clustering
x = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
# Apply K-Means Clustering with 4 clusters
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
# Add cluster labels to the dataset
df['Cluster'] = kmeans.labels_
print(df)
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0             1                 117                      20        2
# 1             2                 107                      59        1
# 2             3                  29                      36        0
# 3             4                 121                      19        2
# 4             5                  86                      90        3
# ..          ...                 ...                     ...      ...
# 169         170                 111                      76        1
# 170         171                 138                      87        1
# 171         172                  84                      15        0
# 172         173                 107                      92        1
# 173         174                  17                      98        3
#
# [174 rows x 4 columns]

# %%
# Visualize the clusters
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster')
plt.title('Customer Clusters (k=4) based on Income & Spending')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend(title='Cluster')
plt.show()
